# %%
import json
import csv

from typing import List

from bs4 import BeautifulSoup
import requests
import tqdm

# %%
base_url = "https://bkdrf.ru"

# %%
url_map = "/map"
resp = requests.get(base_url + url_map)
soup = BeautifulSoup(resp.text, "lxml")

# %%
aglomerations = {}
html_aglomerations = soup.find(id="list-agglomeration").select("a")
for row in html_aglomerations:
    aglomeration = {
        "url": row["href"],
        "name": row.text        
    }
    row_id = row["data-agglomeration-id"]
    aglomerations[row_id] = aglomeration

# %%
agl = aglomerations["tomsk"]
resp = requests.get(base_url + agl['url'])
soup = BeautifulSoup(resp.text, "lxml")

# %%
for script in soup.select("script"):
    if "var demoData" in script.decode():
        break
else:
    script = None

# %%
for line_data in script.decode().split("\n"):
    if "var demoData" in line_data:
        # fix encoding like this: '\\u0022title\\u0022:\\u0022Выполнение работ'
        line_data = line_data.split('"', 1)[1].rsplit('"',1)[0].replace("\\u0022", '"')
        # fix doublequotes escapes: '...\\\\"....'
        line_data = line_data.replace('\\\\"', '\\"')
        break
else:
    line_data = ""

# %%
tomsk_data = json.loads(line_data)

# %%
# tomsk_data["features"][0]
# type, geometry: {type=LineString|Point, coordinates: [[81.0, 58,9], ...]},
# properties: {id:uuid, status:int, worktypeid:uuid,title,victoryroad:bool}

# %%
for feature in tomsk_data.get("features", []):
    props = feature["properties"]
    print(feature["type"], feature["geometry"]["type"], props["status"], props["victoryroad"], props["title"])
# Out:
# Feature LineString 2 False Выполнение работ по ремонту и содержанию автомобильной дороги Могильный Мыс - Парабель - Каргасок на участке км 149+000 - км 157+360 в Каргасокском районе Томской области
# Feature LineString 2 False Выполнение работ по ремонту автомобильной дороги Томск - Каргала - Колпашево на участке км 226+000 - км 249+000 в Чаинском районе Томской области
# Feature LineString 2 False ул. Елизаровых от ул. Елизаровых, 11Б до ул. Шевченко, 55
# Feature LineString 2 False ул. Артема от ул. Артема, 2 до ул. Артема, 22
# Feature LineString 2 False ул. Усова от ул. Усова, 1 до ул. Усова, 9Б
# Feature LineString 2 True ул. 79 Гв. Дивизии от ул. 79 Гв. Дивизии, 1 до ул. 79 Гв. Дивизии, 24
# Feature LineString 2 True ул. 79 Гв. Дивизии от ул. 79 Гв. Дивизии, 1 до ул. 79 Гв. Дивизии, 24
# Feature LineString 2 False ул. Д. Бедного от ул. Д. Бедного, 27 до ул. Д. Бедного, 28
# Feature LineString 2 False пр. Ленина от пр. Ленина, 91 до пр. Ленина, 95
# Feature LineString 2 False Иркутский тракт
# Feature LineString 2 False ул. Мичурина от ул. Мичурина 37 до ул.Мичурина 106
# Feature LineString 2 False ул. Усова от ул. Усова, 11а до ул.Усова, 66
# Feature LineString 2 False ул. Смирнова от ул.Смирнова 1 до ул.Кольцевой проезд 52
# Feature LineString 2 False пр-т Ленина от пр-т Ленина, 1в до пр-т Ленина, 65; от пр-т Ленина, 97 до пл. Ленина, 6
# Feature LineString 2 False ул. Б. Подгорная от ул. Б. Подгорная, 89 до ул. Б. Подгорная, 233
# Feature LineString 2 False ул. Б. Подгорная от ул. Б. Подгорная, 89 до ул. Б. Подгорная, 233
# Feature LineString 2 False ул. Иркутский тракт от ул. Иркутский тракт, 15 до ул. Иркутский тракт, 194/2
# Feature LineString 2 False Транспортная развязка  пр. Комсомольский - ул. Пушкина
# Feature LineString 2 False Транспортная развязка  пр. Комсомольский - ул. Пушкина
# Feature LineString 2 False Автодорога «от ул.Предзаводская до автодороги «Кузовлевский тракт»(ул. Сосновая)
# Feature LineString 2 False ул. Ф. Лыткина
# Feature Point 2 False ул. Яковлева
# Feature LineString 0 False пр.Коммунистического от ул.Свердлова до ул.Леонтичука с восстановлением двух автобусных павильонов
# Feature LineString 2 False автодорога «ул.Чайковского»
# Feature LineString 2 False Московский тракт
# Feature LineString 2 False Автомобильная дорога Нелюбино - Рыбалово - Верхнее Сеченово с подъездом к д.Лаврово (км 0+000 - км 21+198)
# Feature LineString 0 False Выполнение работ по ремонту автомобильной дороги Могильный Мыс - Парабель Каргасок на участке км 157+360 - км 165+962 в Парабельском и Каргасокском районах Томской области
# Feature LineString 2 False Коммунальный мост с подходами (проезжая часть)
# Feature LineString 2 False Коммунальный мост с подходами (проезжая часть)

# %%
len(tomsk_data["features"])
# Out:
# 209

# %%
# load fragment

url_fragment = "/fragmentInfo"

# %%
# # parse fragment

# # header
# soup.find(name="p", attrs={"class": "mm_title"}).text.strip()
# # fragment_title
# p = soup.find(name="div", attrs={"class": "ob_main_info"}).find("p")
# if p.span:
#     p.span.extract()
# p.text.strip()
# props = soup.find("div", attrs={"class": "flex"}).find_all("p")
# for prop in props:
#     print(prop.span.text.strip(), ":\t", prop.span.next_sibling.strip())

# %%
def write_csv(file_name: str, collection: List[dict]):
    # list of columns (for CSV export of variable objects)
    csv_columns = list(set([k for elem in collection for k in elem.keys()]))
    
    with open(file_name, "wt+") as f:
        writer = csv.DictWriter(f, fieldnames=csv_columns)
        writer.writeheader()
        writer.writerows(collection)

# %%
def get_fragment(id_fragment) -> BeautifulSoup:
    resp = requests.get(base_url + url_fragment + "/" + id_fragment)
    return BeautifulSoup(resp.text, "lxml")

# %%
# list with object per fragment
collected_features = []

for feature in tqdm.tqdm(tomsk_data.get("features", [])):
    props = feature["properties"]
    id_fragment = props["id"]
    row = {
        "id_fragment": id_fragment,
        "type": feature.get("type"),
        "geometry_json": json.dumps(feature["geometry"]),
        "status": props.get("status"),
        "worktypeid": props.get("worktypeid"),
        "title": props.get("title"),
        "victoryroad": props.get("victoryroad"),
    }
    
    collected_features.append(row)
# Out:
# 100%|██████████| 209/209 [00:00<00:00, 25685.18it/s]

# %%
fragments = set([f["id_fragment"] for f in collected_features])

collected_fragments = []

for id_fragment in tqdm.tqdm(fragments):
    row = {"id": id_fragment}
    
    fragment_data = get_fragment(id_fragment)

    row["fragment_header"] = fragment_data.find(name="p", attrs={"class": "mm_title"}).text.strip()

    row["fragment_title"] = fragment_data.find(name="div", attrs={"class": "ob_main_info"})\
                            .find("p").span.next_sibling.strip()

    fragment_props = fragment_data.find("div", attrs={"class": "flex"}).find_all("p")
    comments = []
    for prop in fragment_props:
        if prop.span:
            row[prop.span.text.strip()] = prop.span.next_sibling.strip()
        else:
            comments.append(prop.text.strip())
    if comments:
        row["comments"] = "\n".join(comments)
        
    collected_fragments.append(row)
# Out:
# 100%|██████████| 166/166 [01:00<00:00,  2.73it/s]

# %%
write_csv("00_roads.csv", collected_features)
write_csv("00_fragments.csv", collected_fragments)

# %%
aglomerations
# Out:
# {'barnaul': {'url': '/map/barnaul', 'name': 'Алтайский край'},
#  'blagoveshchensk': {'url': '/map/blagoveshchensk',
#   'name': 'Амурская область'},
#  'arhangelsk': {'url': '/map/arhangelsk', 'name': 'Архангельская область'},
#  'astrahan': {'url': '/map/astrahan', 'name': 'Астраханская область'},
#  'belgorod': {'url': '/map/belgorod', 'name': 'Белгородская область'},
#  'bryansk': {'url': '/map/bryansk', 'name': 'Брянская область'},
#  'vladimir': {'url': '/map/vladimir', 'name': 'Владимирская область'},
#  'volgograd': {'url': '/map/volgograd', 'name': 'Волгоградская область'},
#  'vologda': {'url': '/map/vologda', 'name': 'Вологодская область'},
#  'voronezh': {'url': '/map/voronezh', 'name': 'Воронежская область'},
#  'birobidzhan': {'url': '/map/birobidzhan',
#   'name': 'Еврейская автономная область'},
#  'chita': {'url': '/map/chita', 'name': 'Забайкальский край'},
#  'ivanovo': {'url': '/map/ivanovo', 'name': 'Ивановская область'},
#  'irkutsk': {'url': '/map/irkutsk', 'name': 'Иркутская область'},
#  'nalchik': {'url': '/map/nalchik', 'name': 'Кабардино-Балкарская Республика'},
#  'kaliningrad': {'url': '/map/kaliningrad', 'name': 'Калининградская область'},
#  'kaluga': {'url': '/map/kaluga', 'name': 'Калужская область'},
#  'petropavlovsk-kamchatskiy': {'url': '/map/petropavlovsk-kamchatskiy',
#   'name': 'Камчатский край'},
#  'cherkessk': {'url': '/map/cherkessk',
#   'name': 'Карачаево-Черкесская Республика'},
#  'kemerovo': {'url': '/map/kemerovo', 'name': 'Кемеровская область — Кузбасс'},
#  'kirov': {'url': '/map/kirov', 'name': 'Кировская область'},
#  'kostroma': {'url': '/map/kostroma', 'name': 'Костромская область'},
#  'krasnodar': {'url': '/map/krasnodar', 'name': 'Краснодарский край'},
#  'krasnoyarsk': {'url': '/map/krasnoyarsk', 'name': 'Красноярский край'},
#  'kurgan': {'url': '/map/kurgan', 'name': 'Курганская область'},
#  'kursk': {'url': '/map/kursk', 'name': 'Курская область'},
#  'gatchina': {'url': '/map/gatchina', 'name': 'Ленинградская область'},
#  'lipeczk': {'url': '/map/lipeczk', 'name': 'Липецкая область'},
#  'magadan': {'url': '/map/magadan', 'name': 'Магаданская область'},
#  'krasnogorsk': {'url': '/map/krasnogorsk', 'name': 'Московская область'},
#  'murmansk': {'url': '/map/murmansk', 'name': 'Мурманская область'},
#  'naryan-mar': {'url': '/map/naryan-mar', 'name': 'Ненецкий автономный округ'},
#  'novgorod': {'url': '/map/novgorod', 'name': 'Нижегородская область'},
#  'velikiy-novgorod': {'url': '/map/velikiy-novgorod',
#   'name': 'Новгородская область'},
#  'novosibirsk': {'url': '/map/novosibirsk', 'name': 'Новосибирская область'},
#  'omsk': {'url': '/map/omsk', 'name': 'Омская область'},
#  'orenburg': {'url': '/map/orenburg', 'name': 'Оренбургская область'},
#  'orel': {'url': '/map/orel', 'name': 'Орловская область'},
#  'penza': {'url': '/map/penza', 'name': 'Пензенская область'},
#  'perm': {'url': '/map/perm', 'name': 'Пермский край'},
#  'vladivostok': {'url': '/map/vladivostok', 'name': 'Приморский край'},
#  'pskov': {'url': '/map/pskov', 'name': 'Псковская область'},
#  'maikop': {'url': '/map/maikop', 'name': 'Республика Адыгея'},
#  'gorno-altaisk': {'url': '/map/gorno-altaisk', 'name': 'Республика Алтай'},
#  'ufa': {'url': '/map/ufa', 'name': 'Республика Башкортостан'},
#  'ulan-ude': {'url': '/map/ulan-ude', 'name': 'Республика Бурятия'},
#  'mahachkala': {'url': '/map/mahachkala', 'name': 'Республика Дагестан'},
#  'magas': {'url': '/map/magas', 'name': 'Республика Ингушетия'},
#  'elista': {'url': '/map/elista', 'name': 'Республика Калмыкия'},
#  'petrozavodsk': {'url': '/map/petrozavodsk', 'name': 'Республика Карелия'},
#  'syktyvkar': {'url': '/map/syktyvkar', 'name': 'Республика Коми'},
#  'cimferopol': {'url': '/map/cimferopol', 'name': 'Республика Крым'},
#  'yoshkar-ola': {'url': '/map/yoshkar-ola', 'name': 'Республика Марий Эл'},
#  'saransk': {'url': '/map/saransk', 'name': 'Республика Мордовия'},
#  'yakutsk': {'url': '/map/yakutsk', 'name': 'Республика Саха (Якутия)'},
#  'vladikavkaz': {'url': '/map/vladikavkaz',
#   'name': 'Республика Северная Осетия — Алания'},
#  'kazan': {'url': '/map/kazan', 'name': 'Республика Татарстан'},
#  'kyzyl': {'url': '/map/kyzyl', 'name': 'Республика Тыва'},
#  'abakan': {'url': '/map/abakan', 'name': 'Республика Хакасия'},
#  'rostov-na-donu': {'url': '/map/rostov-na-donu',
#   'name': 'Ростовская область'},
#  'ryazan': {'url': '/map/ryazan', 'name': 'Рязанская область'},
#  'samara': {'url': '/map/samara', 'name': 'Самарская область'},
#  'saintpetersburg': {'url': '/map/saintpetersburg', 'name': 'Санкт-Петербург'},
#  'saratov': {'url': '/map/saratov', 'name': 'Саратовская область'},
#  'yuzhno-sahalinsk': {'url': '/map/yuzhno-sahalinsk',
#   'name': 'Сахалинская область'},
#  'ekaterinburg': {'url': '/map/ekaterinburg', 'name': 'Свердловская область'},
#  'sevastopol': {'url': '/map/sevastopol', 'name': 'Севастополь'},
#  'smolensk': {'url': '/map/smolensk', 'name': 'Смоленская область'},
#  'stavropol': {'url': '/map/stavropol', 'name': 'Ставропольский край'},
#  'tambov': {'url': '/map/tambov', 'name': 'Тамбовская область'},
#  'tver': {'url': '/map/tver', 'name': 'Тверская область'},
#  'tomsk': {'url': '/map/tomsk', 'name': 'Томская область'},
#  'tula': {'url': '/map/tula', 'name': 'Тульская область'},
#  'tyumen': {'url': '/map/tyumen', 'name': 'Тюменская область'},
#  'izhevsk': {'url': '/map/izhevsk', 'name': 'Удмуртская Республика'},
#  'ulyanovsk': {'url': '/map/ulyanovsk', 'name': 'Ульяновская область'},
#  'habarovsk': {'url': '/map/habarovsk', 'name': 'Хабаровский край'},
#  'hanty-mansiysk': {'url': '/map/hanty-mansiysk',
#   'name': 'Ханты-Мансийский автономный округ'},
#  'chelyabinsk': {'url': '/map/chelyabinsk', 'name': 'Челябинская область'},
#  'grozny': {'url': '/map/grozny', 'name': 'Чеченская Республика'},
#  'cheboksary': {'url': '/map/cheboksary', 'name': 'Чувашская Республика'},
#  'anadyr': {'url': '/map/anadyr', 'name': 'Чукотский автономный округ'},
#  'salehard': {'url': '/map/salehard',
#   'name': 'Ямало-Ненецкий автономный округ'},
#  'yaroslavl': {'url': '/map/yaroslavl', 'name': 'Ярославская область'}}
