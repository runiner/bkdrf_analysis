# %%
# %matplotlib inline

# %%
import json
import csv

import pandas as pd
import numpy as np

# %%
import seaborn as sns
sns.set_style("whitegrid")
import matplotlib
matplotlib.rcParams['figure.figsize'] = (15.0, 8.0)

# %%
from icecream import ic

# %%
region_name = "Томск"
region_data_file = "tomskaia-oblast.geojson"  # from https://dtp-stat.ru/opendata/

# %%
def get_dtp_by_region():
    def check_region(item):
        return item["properties"]["region"] == region_name

    with open(region_data_file, "rt") as f:
        dtp = json.load(f)

    res = list(filter(check_region, dtp["features"]))
    print(f'всего ДТП в регионе "{region_name}": {len(res)}')
    return res
dtp_tomsk = get_dtp_by_region()
# Out:
# всего ДТП в регионе "Томск": 2318

# %%
def feature_extractor(it):
    res = {
        "id": it["properties"]["id"],
        "datetime": it["properties"]["datetime"],
        "lat": it["properties"]["point"]["lat"],
        "lon": it["properties"]["point"]["long"],
        "severity": it["properties"]["severity"],
        "address": it["properties"]["address"],
        "dead_count": it["properties"]["dead_count"],
        "injured_count": it["properties"]["injured_count"],
    }
    return res
df_dtp = pd.DataFrame(map(feature_extractor, dtp_tomsk))
df_dtp.datetime = df_dtp.datetime.astype(np.datetime64)
df_dtp.head()
# Out:
#         id            datetime        lat        lon     severity  \
# 0  2528452 2020-12-20 23:02:00  56.503054  84.958584       Легкий
# 1  2503256 2020-10-07 20:15:00  56.576648  85.105934  С погибшими
# 2  2539023 2021-01-31 08:20:00  56.496890  84.968401       Легкий
# 3  2539024 2021-01-30 14:30:00  56.462004  84.989151       Легкий
# 4  2539025 2021-01-29 21:36:00  56.480713  85.033740      Тяжёлый
#
#                               address  dead_count  injured_count
# 0  г Томск, ул Дальне-Ключевская, 25Б           0              1
# 1    г Томск, Кузовлево-Светлый, 6 км           1              0
# 2             г Томск, ул Яковлева, 9           0              1
# 3                                None           0              1
# 4           г Томск, ул Писемского, 8           0              1

# %%
repairs = []
with open("00_fragments.csv", "rt") as f:
    reader = csv.reader(f)
    header = next(reader)
    print("Header columns:", header)
    for row in reader:
        repairs.append(dict(zip(header,row)))
df_repairs = pd.DataFrame(repairs)

df_repairs[["work_start", "work_end"]] = df_repairs["Срок выполнения работ на объекте"]\
    .str.split(" ‒ ", n=1, expand=True).astype(np.datetime64)

df_repairs.head()
# Out:
# Header columns: ['Год работ', 'fragment_header', 'fragment_title', 'comments', 'id', 'Статус', 'Срок выполнения работ на объекте', 'Тип работ']
#   Год работ                 fragment_header  \
# 0      2021                          Ремонт
# 1      2017  Ремонт покрытия проезжей части
# 2      2020                          Ремонт
# 3      2018  Ремонт покрытия проезжей части
# 4      2018  Ремонт покрытия проезжей части
#
#                                       fragment_title comments  \
# 0  пр.Коммунистического от ул.Свердлова до ул.Лео...
# 1                             Автодорога «ул.Кирова»
# 2  ул.Крупской: от просп.Коммунистического до ул....
# 3                                        ул. Войкова
# 4                           ул. Набережная р. Ушайки
#
#                                      id        Статус  \
# 0  e8809a70-2216-4bee-922b-154d73ae493f  Запланирован
# 1  70ee27cb-ab73-4efb-bcc2-93c0b5a4b85c      Завершен
# 2  4a52c0b2-7805-4bf1-b9b7-d090263c28de      Завершен
# 3  56402bec-90dc-4184-bbda-07e4a7191180      Завершен
# 4  25d81872-36a6-4066-8132-58f14f969e50      Завершен
#
#   Срок выполнения работ на объекте                       Тип работ work_start  \
# 0          25.04.2021 ‒ 01.09.2021                          Ремонт 2021-04-25
# 1          01.06.2017 ‒ 31.07.2017  Ремонт покрытия проезжей части 2017-01-06
# 2          25.04.2020 ‒ 31.08.2020                          Ремонт 2020-04-25
# 3          01.05.2018 ‒ 01.09.2018  Ремонт покрытия проезжей части 2018-01-05
# 4          01.05.2018 ‒ 01.09.2018  Ремонт покрытия проезжей части 2018-01-05
#
#     work_end
# 0 2021-01-09
# 1 2017-07-31
# 2 2020-08-31
# 3 2018-01-09
# 4 2018-01-09

# %%
with open("01_dtp_to_fragments.json", "rt") as f:
    dtp_to_repair = json.load(f)
df_dtp_to_repair = pd.DataFrame(dtp_to_repair)

# %%
# for every repair match all related DTPs
df_merged = df_repairs\
    .merge(df_dtp_to_repair, left_on="id", right_on="fragment")\
    .merge(df_dtp, left_on="dtp_id", right_on="id", suffixes=("_repair", "_dtp"))

# %%
df_merged.severity = df_merged.severity.astype("category")
df_merged.severity.cat.set_categories(["Легкий", "Тяжёлый", "С погибшими"], inplace=True)  # sorting order

# %%
df_merged
# Out:
#      Год работ                 fragment_header  \
# 0         2018  Ремонт покрытия проезжей части
# 1         2018  Ремонт покрытия проезжей части
# 2         2018  Ремонт покрытия проезжей части
# 3         2017  Ремонт покрытия проезжей части
# 4         2017  Ремонт покрытия проезжей части
# ...        ...                             ...
# 1426      2017  Ремонт покрытия проезжей части
# 1427      2017  Ремонт покрытия проезжей части
# 1428      2017  Ремонт покрытия проезжей части
# 1429      2017  Ремонт покрытия проезжей части
# 1430      2017  Ремонт покрытия проезжей части
#
#                                          fragment_title comments  \
# 0                                           ул. Войкова
# 1                              ул. Набережная р. Ушайки
# 2                              ул. Набережная р. Ушайки
# 3     Автомобильная дорога Томск - Мирный - Меженино...
# 4     Автомобильная дорога Томск - Мирный - Меженино...
# ...                                                 ...      ...
# 1426                                   Чекистский тракт
# 1427                                   Чекистский тракт
# 1428                                   Чекистский тракт
# 1429                                   Чекистский тракт
# 1430                                   Чекистский тракт
#
#                                  id_repair    Статус  \
# 0     56402bec-90dc-4184-bbda-07e4a7191180  Завершен
# 1     25d81872-36a6-4066-8132-58f14f969e50  Завершен
# 2     25d81872-36a6-4066-8132-58f14f969e50  Завершен
# 3     cf61a288-bf68-4df7-9209-ce56dda01abf  Завершен
# 4     cf61a288-bf68-4df7-9209-ce56dda01abf  Завершен
# ...                                    ...       ...
# 1426  c1604843-8c3a-46f6-a7e0-6d6ff5841a68  Завершен
# 1427  c1604843-8c3a-46f6-a7e0-6d6ff5841a68  Завершен
# 1428  c1604843-8c3a-46f6-a7e0-6d6ff5841a68  Завершен
# 1429  c1604843-8c3a-46f6-a7e0-6d6ff5841a68  Завершен
# 1430  c1604843-8c3a-46f6-a7e0-6d6ff5841a68  Завершен
#
#      Срок выполнения работ на объекте                       Тип работ  \
# 0             01.05.2018 ‒ 01.09.2018  Ремонт покрытия проезжей части
# 1             01.05.2018 ‒ 01.09.2018  Ремонт покрытия проезжей части
# 2             01.05.2018 ‒ 01.09.2018  Ремонт покрытия проезжей части
# 3             19.06.2017 ‒ 10.10.2017  Ремонт покрытия проезжей части
# 4             19.06.2017 ‒ 10.10.2017  Ремонт покрытия проезжей части
# ...                               ...                             ...
# 1426          18.04.2017 ‒ 05.10.2017  Ремонт покрытия проезжей части
# 1427          18.04.2017 ‒ 05.10.2017  Ремонт покрытия проезжей части
# 1428          18.04.2017 ‒ 05.10.2017  Ремонт покрытия проезжей части
# 1429          18.04.2017 ‒ 05.10.2017  Ремонт покрытия проезжей части
# 1430          18.04.2017 ‒ 05.10.2017  Ремонт покрытия проезжей части
#
#      work_start   work_end   dtp_id                              fragment  \
# 0    2018-01-05 2018-01-09  2515609  56402bec-90dc-4184-bbda-07e4a7191180
# 1    2018-01-05 2018-01-09  2281358  25d81872-36a6-4066-8132-58f14f969e50
# 2    2018-01-05 2018-01-09  2282285  25d81872-36a6-4066-8132-58f14f969e50
# 3    2017-06-19 2017-10-10  2279868  cf61a288-bf68-4df7-9209-ce56dda01abf
# 4    2017-06-19 2017-10-10  2281089  cf61a288-bf68-4df7-9209-ce56dda01abf
# ...         ...        ...      ...                                   ...
# 1426 2017-04-18 2017-05-10  2282870  c1604843-8c3a-46f6-a7e0-6d6ff5841a68
# 1427 2017-04-18 2017-05-10  2282978  c1604843-8c3a-46f6-a7e0-6d6ff5841a68
# 1428 2017-04-18 2017-05-10  2279075  c1604843-8c3a-46f6-a7e0-6d6ff5841a68
# 1429 2017-04-18 2017-05-10  2528444  c1604843-8c3a-46f6-a7e0-6d6ff5841a68
# 1430 2017-04-18 2017-05-10  2280141  c1604843-8c3a-46f6-a7e0-6d6ff5841a68
#
#        id_dtp            datetime        lat        lon severity  \
# 0     2515609 2020-11-11 23:32:00  56.502616  84.940903  Тяжёлый
# 1     2281358 2018-09-30 01:00:00  56.484985  84.950205   Легкий
# 2     2282285 2015-07-16 15:30:00  56.486667  84.950556  Тяжёлый
# 3     2279868 2017-06-18 03:25:00  56.452800  85.030600  Тяжёлый
# 4     2281089 2016-08-25 22:05:00  56.451900  85.035000   Легкий
# ...       ...                 ...        ...        ...      ...
# 1426  2282870 2018-01-09 14:30:00  56.548300  84.971700  Тяжёлый
# 1427  2282978 2016-10-28 11:30:00  56.547500  84.971100  Тяжёлый
# 1428  2279075 2018-06-18 07:50:00  56.538648  84.965129   Легкий
# 1429  2528444 2020-12-31 20:28:00  56.537719  84.965333  Тяжёлый
# 1430  2280141 2018-12-15 23:05:00  56.537713  84.965268   Легкий
#
#                                      address  dead_count  injured_count
# 0                 г Томск, пер Заозерный, 3а           0              1
# 1                                       None           0              1
# 2     г Томск, ул Набережная реки Ушайки, 4а           0              1
# 3       г Томск, ул Богдана Хмельницкого, 60           0              1
# 4               г Томск, ул Степная 1-я, 12а           0              1
# ...                                      ...         ...            ...
# 1426         г Томск, тракт Кузовлевский, 24           0              3
# 1427         г Томск, тракт Кузовлевский, 24           0              1
# 1428         г Томск, тракт Кузовлевский, 31           0              1
# 1429                г Томск, ул Кутузова, 1А           0              1
# 1430         г Томск, тракт Кузовлевский, 31           0              1
#
# [1431 rows x 20 columns]

# %%
# assign "before", "during", or "after" based on DTP datetime and repair begun/finished 
df_merged["repair_relation"] = np.where(df_merged.datetime < df_merged.work_start, "before",
                                        np.where(df_merged.datetime > df_merged.work_start, "after",
                                                 "during"))
# df_merged.repair_relation = df_merged.repair_relation.astype("category")
# df_merged.repair_relation.cat.set_categories(["before", "during", "after"], inplace=True)  # sorting order

# %%
# Count period lengths
dtp_first_day = np.datetime64("2015-01-01")
dtp_last_day = np.datetime64("2021-02-28")

df_merged["total_days"] = np.where(df_merged.repair_relation=="before", df_merged.work_start-dtp_first_day,
                                   np.where(df_merged.repair_relation=="after", dtp_last_day-df_merged.work_end,
                                   df_merged.work_end-df_merged.work_start))
# converting to ints
df_merged["total_days"] = df_merged.total_days.dt.days

# %%
dtp_2020 = df_merged[df_merged["Год работ"] == "2020"]
print("Всего ДТП, на дорогах отремонтированных в 2020-ом году: ", dtp_2020.shape[0])
print("Из них до ремонта (2015-2020): ", dtp_2020[dtp_2020.repair_relation=="before"].shape[0])
print("Из них после ремонта (2020-начало 2021): ", dtp_2020[dtp_2020.repair_relation=="after"].shape[0])
dtp_2020[dtp_2020.repair_relation=="after"][[
 'fragment_title',
 'Срок выполнения работ на объекте',
 'datetime',
 'severity',
 'address',
 'dead_count',
 'injured_count']]
# Out:
# Всего ДТП, на дорогах отремонтированных в 2020-ом году:  170
# Из них до ремонта (2015-2020):  151
# Из них после ремонта (2020-начало 2021):  19
#                                          fragment_title  \
# 101   ул. 79 Гв. Дивизии от ул. 79 Гв. Дивизии, 1 до...
# 120   ул. 79 Гв. Дивизии от ул. 79 Гв. Дивизии, 1 до...
# 122   ул. 79 Гв. Дивизии от ул. 79 Гв. Дивизии, 1 до...
# 431   ул. Пролетарская от ул. Пролетарская, 2 до пр....
# 436   ул. Пролетарская от ул. Пролетарская, 2 до пр....
# 468   ул. Елизаровых от ул. Елизаровых, 11Б до ул. Ш...
# 469   ул. Елизаровых от ул. Елизаровых, 11Б до ул. Ш...
# 470   ул. Елизаровых от ул. Елизаровых, 11Б до ул. Ш...
# 491   ул. Елизаровых от ул. Елизаровых, 11Б до ул. Ш...
# 558   ул. Косарева от ул. Косарева, 1/1 до ул. Косар...
# 570   ул. Косарева от ул. Косарева, 1/1 до ул. Косар...
# 588       ул. Пушкина от пл. Соляная, 11 до путепровода
# 589       ул. Пушкина от пл. Соляная, 11 до путепровода
# 602       ул. Пушкина от пл. Соляная, 11 до путепровода
# 621       ул. Пушкина от пл. Соляная, 11 до путепровода
# 869       ул. Артема от ул. Артема, 2 до ул. Артема, 22
# 870       ул. Артема от ул. Артема, 2 до ул. Артема, 22
# 871       ул. Артема от ул. Артема, 2 до ул. Артема, 22
# 1164                                    Иркутский тракт
#
#      Срок выполнения работ на объекте            datetime     severity  \
# 101           15.05.2020 ‒ 30.08.2020 2021-01-20 10:30:00  С погибшими
# 120           15.05.2020 ‒ 30.08.2020 2020-09-03 21:00:00      Тяжёлый
# 122           15.05.2020 ‒ 30.08.2020 2020-12-06 00:10:00       Легкий
# 431           15.05.2020 ‒ 30.08.2020 2021-01-13 18:55:00      Тяжёлый
# 436           15.05.2020 ‒ 30.08.2020 2020-11-01 19:10:00       Легкий
# 468           15.05.2020 ‒ 30.08.2020 2021-01-30 14:30:00       Легкий
# 469           15.05.2020 ‒ 30.08.2020 2021-02-13 17:50:00       Легкий
# 470           15.05.2020 ‒ 30.08.2020 2020-10-12 07:30:00      Тяжёлый
# 491           15.05.2020 ‒ 30.08.2020 2020-06-27 10:55:00      Тяжёлый
# 558           15.05.2020 ‒ 30.08.2020 2020-09-09 13:50:00      Тяжёлый
# 570           15.05.2020 ‒ 30.08.2020 2020-11-25 10:25:00       Легкий
# 588           15.05.2020 ‒ 30.08.2020 2020-10-14 08:35:00       Легкий
# 589           15.05.2020 ‒ 30.08.2020 2020-10-06 23:40:00       Легкий
# 602           15.05.2020 ‒ 30.08.2020 2020-08-21 17:11:00      Тяжёлый
# 621           15.05.2020 ‒ 30.08.2020 2020-07-02 23:40:00      Тяжёлый
# 869           15.05.2020 ‒ 30.08.2020 2020-08-01 01:33:00      Тяжёлый
# 870           15.05.2020 ‒ 30.08.2020 2020-10-28 18:55:00      Тяжёлый
# 871           15.05.2020 ‒ 30.08.2020 2020-09-25 17:30:00       Легкий
# 1164          22.04.2020 ‒ 30.08.2020 2020-12-09 19:05:00       Легкий
#
#                                       address  dead_count  injured_count
# 101     г Томск, ул 79 Гвардейской Дивизии, 3           1              1
# 120   г Томск, ул 79 Гвардейской Дивизии, 2 Б           0              1
# 122     г Томск, ул 79 Гвардейской Дивизии, 6           0              1
# 431              г Томск, ул Пролетарская, 18           0              1
# 436                г Томск, пр-кт Ленина, 196           0              1
# 468                                      None           0              1
# 469                г Томск, ул Елизаровых, 22           0              1
# 470                г Томск, ул Елизаровых, 50           0              1
# 491                г Томск, ул Елизаровых, 2а           0              1
# 558                  г Томск, ул Косарева, 33           0              1
# 570         г Томск, ул Красноармейская, 128А           0              1
# 588                  г Томск, ул Пушкина, 27д           0              1
# 589                 г Томск, ул Пушкина, 46 1           0              2
# 602                  г Томск, ул Пушкина, 42А           0              2
# 621              г Томск, ул Пушкина, 61 ст.1           0              3
# 869                г Томск, ул Елизаровых, 18           0              1
# 870                     г Томск, ул Артема, 3           0              1
# 871                     г Томск, ул Усова, 58           0              1
# 1164              г Томск, тракт Иркутский, 2           0              1

# %%
# remove 2021 year, because it holds future (planned) repairs
df_grouped = df_merged[(df_merged["Год работ"] != "2021") & (df_merged.repair_relation != "during")]\
        .groupby(["fragment_title", "repair_relation"])\
        .agg(totals=("id_repair", "count"), days=("total_days", "first"), year=("Год работ", "first"))

df_grouped["ratio"] = df_grouped.totals/df_grouped.days*365

df_grouped = df_grouped.unstack()

df_grouped.columns = [f"{a}_{b}" for a, b in df_grouped.columns]
df_grouped = df_grouped.drop(columns=["year_before"]).rename(columns={"year_after": "year"})
df_grouped
# Out:
#                                                     totals_after  \
# fragment_title
# Автодорога "Томск-ТНХК"                                      3.0
# Автомобильная дорога Кузовлево - Светлый (км 0+...          13.0
# Автомобильная дорога Михайловка - Александровск...           5.0
# Автомобильная дорога Томск - Аэропорт (км 2+500...          16.0
# Автомобильная дорога Томск - Каргала - Колпашев...          11.0
# ...                                                          ...
# ул. Усова от ул. Усова, 11а до ул.Усова, 66                  1.0
# ул. Учебная                                                 20.0
# ул. Ф. Лыткина                                               1.0
# ул. Шевченко                                                 6.0
# ул. Энергетическая                                           1.0
#
#                                                     totals_before  days_after  \
# fragment_title
# Автодорога "Томск-ТНХК"                                       2.0      1280.0
# Автомобильная дорога Кузовлево - Светлый (км 0+...            6.0      1237.0
# Автомобильная дорога Михайловка - Александровск...            NaN      1511.0
# Автомобильная дорога Томск - Аэропорт (км 2+500...           15.0      1146.0
# Автомобильная дорога Томск - Каргала - Колпашев...            9.0      1217.0
# ...                                                           ...         ...
# ул. Усова от ул. Усова, 11а до ул.Усова, 66                   7.0       507.0
# ул. Учебная                                                   9.0      1277.0
# ул. Ф. Лыткина                                                5.0      1146.0
# ул. Шевченко                                                  6.0      1146.0
# ул. Энергетическая                                            1.0      1277.0
#
#                                                     days_before  year  \
# fragment_title
# Автодорога "Томск-ТНХК"                                   737.0  2017
# Автомобильная дорога Кузовлево - Светлый (км 0+...        837.0  2017
# Автомобильная дорога Михайловка - Александровск...          NaN  2017
# Автомобильная дорога Томск - Аэропорт (км 2+500...       1099.0  2018
# Автомобильная дорога Томск - Каргала - Колпашев...        856.0  2017
# ...                                                         ...   ...
# ул. Усова от ул. Усова, 11а до ул.Усова, 66              1595.0  2019
# ул. Учебная                                               766.0  2017
# ул. Ф. Лыткина                                           1100.0  2018
# ул. Шевченко                                             1100.0  2018
# ул. Энергетическая                                        838.0  2017
#
#                                                     ratio_after  ratio_before
# fragment_title
# Автодорога "Томск-ТНХК"                                0.855469      0.990502
# Автомобильная дорога Кузовлево - Светлый (км 0+...     3.835893      2.616487
# Автомобильная дорога Михайловка - Александровск...     1.207809           NaN
# Автомобильная дорога Томск - Аэропорт (км 2+500...     5.095986      4.981802
# Автомобильная дорога Томск - Каргала - Колпашев...     3.299096      3.837617
# ...                                                         ...           ...
# ул. Усова от ул. Усова, 11а до ул.Усова, 66            0.719921      1.601881
# ул. Учебная                                            5.716523      4.288512
# ул. Ф. Лыткина                                         0.318499      1.659091
# ул. Шевченко                                           1.910995      1.990909
# ул. Энергетическая                                     0.285826      0.435561
#
# [76 rows x 7 columns]

# %%
df_grouped["change"] = df_grouped.ratio_after/df_grouped.ratio_before

df_to_save = df_grouped[(df_grouped.ratio_after > 2) | (df_grouped.ratio_before > 2)].dropna().sort_values("change")

df_to_save
# Out:
#                                                     totals_after  \
# fragment_title
# Коммунальный мост с подходами (проезжая часть)               1.0
# Автомобильная дорога Томск - Мариинск (км0+000 ...           5.0
# ул. Советская                                                3.0
# ул. Смирнова от ул.Смирнова 1 до ул.Кольцевой п...           6.0
# ул. Гоголя                                                   6.0
# ул. Р. Люксембург                                           20.0
# Автомобильная дорога Томск - Каргала - Колпашев...          11.0
# ул. Тверская                                                 9.0
# Московский тракт                                            11.0
# ул. С. Лазо                                                 24.0
# ул. Елизаровых                                               7.0
# пр. Комсомольский                                           37.0
# пр-т Ленина от пр-т Ленина, 1в до пр-т Ленина, ...          24.0
# Автомобильная дорога Томск - Аэропорт (км 2+500...          16.0
# пр. Мира                                                    30.0
# пр. Кирова                                                  40.0
# ул. Б. Подгорная от ул. Б. Подгорная, 89 до ул....           7.0
# ул. Осенняя                                                  7.0
# ул. Иркутский тракт от ул. Иркутский тракт, 15 ...          27.0
# ул. Елизаровых от ул. Елизаровых, 11Б до ул. Ше...           4.0
# ул. 79 Гв. Дивизии от ул. 79 Гв. Дивизии, 1 до ...           3.0
# ул. Учебная                                                 20.0
# ул. Пушкина от пл. Соляная, 11 до путепровода                4.0
# ул. Балтийская                                               9.0
# Автомобильная дорога Кузовлево - Светлый (км 0+...          13.0
# ул. Вершинина                                               11.0
# Чекистский тракт                                             8.0
# ул. Косарева от ул. Косарева, 1/1 до ул. Косаре...           2.0
# ул. Киевская                                                26.0
# ул. Б. Хмельницкого                                         10.0
# ул. Мичурина от ул. Мичурина 37 до ул.Мичурина 106          19.0
# ул. Герцена                                                  8.0
# ул. Пролетарская от ул. Пролетарская, 2 до пр. ...           2.0
# Иркутский тракт                                              5.0
# ул. Водяная                                                  8.0
#
#                                                     totals_before  days_after  \
# fragment_title
# Коммунальный мост с подходами (проезжая часть)                7.0      1277.0
# Автомобильная дорога Томск - Мариинск (км0+000 ...           12.0      1217.0
# ул. Советская                                                 8.0      1146.0
# ул. Смирнова от ул.Смирнова 1 до ул.Кольцевой п...           22.0       568.0
# ул. Гоголя                                                    5.0      1277.0
# ул. Р. Люксембург                                            16.0      1247.0
# Автомобильная дорога Томск - Каргала - Колпашев...            9.0      1217.0
# ул. Тверская                                                 10.0      1146.0
# Московский тракт                                             12.0      1146.0
# ул. С. Лазо                                                  24.0      1146.0
# ул. Елизаровых                                                7.0      1146.0
# пр. Комсомольский                                            29.0      1277.0
# пр-т Ленина от пр-т Ленина, 1в до пр-т Ленина, ...           74.0       507.0
# Автомобильная дорога Томск - Аэропорт (км 2+500...           15.0      1146.0
# пр. Мира                                                     27.0      1146.0
# пр. Кирова                                                   29.0      1277.0
# ул. Б. Подгорная от ул. Б. Подгорная, 89 до ул....           19.0       527.0
# ул. Осенняя                                                   6.0      1146.0
# ул. Иркутский тракт от ул. Иркутский тракт, 15 ...           71.0       527.0
# ул. Елизаровых от ул. Елизаровых, 11Б до ул. Ше...           35.0       182.0
# ул. 79 Гв. Дивизии от ул. 79 Гв. Дивизии, 1 до ...           26.0       182.0
# ул. Учебная                                                   9.0      1277.0
# ул. Пушкина от пл. Соляная, 11 до путепровода                32.0       182.0
# ул. Балтийская                                                6.0      1146.0
# Автомобильная дорога Кузовлево - Светлый (км 0+...            6.0      1237.0
# ул. Вершинина                                                 7.0      1146.0
# Чекистский тракт                                              3.0      1390.0
# ул. Косарева от ул. Косарева, 1/1 до ул. Косаре...           13.0       182.0
# ул. Киевская                                                  9.0      1277.0
# ул. Б. Хмельницкого                                           3.0      1277.0
# ул. Мичурина от ул. Мичурина 37 до ул.Мичурина 106           24.0       527.0
# ул. Герцена                                                   3.0      1146.0
# ул. Пролетарская от ул. Пролетарская, 2 до пр. ...            8.0       182.0
# Иркутский тракт                                              18.0       182.0
# ул. Водяная                                                   2.0      1146.0
#
#                                                     days_before  year  \
# fragment_title
# Коммунальный мост с подходами (проезжая часть)            929.0  2017
# Автомобильная дорога Томск - Мариинск (км0+000 ...        930.0  2017
# ул. Советская                                            1100.0  2018
# ул. Смирнова от ул.Смирнова 1 до ул.Кольцевой п...       1595.0  2019
# ул. Гоголя                                                838.0  2017
# ул. Р. Люксембург                                         838.0  2017
# Автомобильная дорога Томск - Каргала - Колпашев...        856.0  2017
# ул. Тверская                                             1100.0  2018
# Московский тракт                                         1100.0  2018
# ул. С. Лазо                                              1100.0  2018
# ул. Елизаровых                                           1100.0  2018
# пр. Комсомольский                                        1007.0  2017
# пр-т Ленина от пр-т Ленина, 1в до пр-т Ленина, ...       1595.0  2019
# Автомобильная дорога Томск - Аэропорт (км 2+500...       1099.0  2018
# пр. Мира                                                 1100.0  2018
# пр. Кирова                                               1007.0  2017
# ул. Б. Подгорная от ул. Б. Подгорная, 89 до ул....       1595.0  2019
# ул. Осенняя                                              1100.0  2018
# ул. Иркутский тракт от ул. Иркутский тракт, 15 ...       1595.0  2019
# ул. Елизаровых от ул. Елизаровых, 11Б до ул. Ше...       1961.0  2020
# ул. 79 Гв. Дивизии от ул. 79 Гв. Дивизии, 1 до ...       1961.0  2020
# ул. Учебная                                               766.0  2017
# ул. Пушкина от пл. Соляная, 11 до путепровода            1961.0  2020
# ул. Балтийская                                           1100.0  2018
# Автомобильная дорога Кузовлево - Светлый (км 0+...        837.0  2017
# ул. Вершинина                                            1100.0  2018
# Чекистский тракт                                          838.0  2017
# ул. Косарева от ул. Косарева, 1/1 до ул. Косаре...       1961.0  2020
# ул. Киевская                                              766.0  2017
# ул. Б. Хмельницкого                                       766.0  2017
# ул. Мичурина от ул. Мичурина 37 до ул.Мичурина 106       1595.0  2019
# ул. Герцена                                              1100.0  2018
# ул. Пролетарская от ул. Пролетарская, 2 до пр. ...       1961.0  2020
# Иркутский тракт                                          1938.0  2020
# ул. Водяная                                              1100.0  2018
#
#                                                     ratio_after  ratio_before  \
# fragment_title
# Коммунальный мост с подходами (проезжая часть)         0.285826      2.750269
# Автомобильная дорога Томск - Мариинск (км0+000 ...     1.499589      4.709677
# ул. Советская                                          0.955497      2.654545
# ул. Смирнова от ул.Смирнова 1 до ул.Кольцевой п...     3.855634      5.034483
# ул. Гоголя                                             1.714957      2.177804
# ул. Р. Люксембург                                      5.854050      6.968974
# Автомобильная дорога Томск - Каргала - Колпашев...     3.299096      3.837617
# ул. Тверская                                           2.866492      3.318182
# Московский тракт                                       3.503490      3.981818
# ул. С. Лазо                                            7.643979      7.963636
# ул. Елизаровых                                         2.229494      2.322727
# пр. Комсомольский                                     10.575568     10.511420
# пр-т Ленина от пр-т Ленина, 1в до пр-т Ленина, ...    17.278107     16.934169
# Автомобильная дорога Томск - Аэропорт (км 2+500...     5.095986      4.981802
# пр. Мира                                               9.554974      8.959091
# пр. Кирова                                            11.433046     10.511420
# ул. Б. Подгорная от ул. Б. Подгорная, 89 до ул....     4.848197      4.347962
# ул. Осенняя                                            2.229494      1.990909
# ул. Иркутский тракт от ул. Иркутский тракт, 15 ...    18.700190     16.247649
# ул. Елизаровых от ул. Елизаровых, 11Б до ул. Ше...     8.021978      6.514533
# ул. 79 Гв. Дивизии от ул. 79 Гв. Дивизии, 1 до ...     6.016484      4.839368
# ул. Учебная                                            5.716523      4.288512
# ул. Пушкина от пл. Соляная, 11 до путепровода          8.021978      5.956145
# ул. Балтийская                                         2.866492      1.990909
# Автомобильная дорога Кузовлево - Светлый (км 0+...     3.835893      2.616487
# ул. Вершинина                                          3.503490      2.322727
# Чекистский тракт                                       2.100719      1.306683
# ул. Косарева от ул. Косарева, 1/1 до ул. Косаре...     4.010989      2.419684
# ул. Киевская                                           7.431480      4.288512
# ул. Б. Хмельницкого                                    2.858262      1.429504
# ул. Мичурина от ул. Мичурина 37 до ул.Мичурина 106    13.159393      5.492163
# ул. Герцена                                            2.547993      0.995455
# ул. Пролетарская от ул. Пролетарская, 2 до пр. ...     4.010989      1.489036
# Иркутский тракт                                       10.027473      3.390093
# ул. Водяная                                            2.547993      0.663636
#
#                                                       change
# fragment_title
# Коммунальный мост с подходами (проезжая часть)      0.103927
# Автомобильная дорога Томск - Мариинск (км0+000 ...  0.318406
# ул. Советская                                       0.359948
# ул. Смирнова от ул.Смирнова 1 до ул.Кольцевой п...  0.765845
# ул. Гоголя                                          0.787471
# ул. Р. Люксембург                                   0.840016
# Автомобильная дорога Томск - Каргала - Колпашев...  0.859673
# ул. Тверская                                        0.863874
# Московский тракт                                    0.879872
# ул. С. Лазо                                         0.959860
# ул. Елизаровых                                      0.959860
# пр. Комсомольский                                   1.006103
# пр-т Ленина от пр-т Ленина, 1в до пр-т Ленина, ...  1.020310
# Автомобильная дорога Томск - Аэропорт (км 2+500...  1.022920
# пр. Мира                                            1.066512
# пр. Кирова                                          1.087679
# ул. Б. Подгорная от ул. Б. Подгорная, 89 до ул....  1.115050
# ул. Осенняя                                         1.119837
# ул. Иркутский тракт от ул. Иркутский тракт, 15 ...  1.150947
# ул. Елизаровых от ул. Елизаровых, 11Б до ул. Ше...  1.231397
# ул. 79 Гв. Дивизии от ул. 79 Гв. Дивизии, 1 до ...  1.243238
# ул. Учебная                                         1.332985
# ул. Пушкина от пл. Соляная, 11 до путепровода       1.346841
# ул. Балтийская                                      1.439791
# Автомобильная дорога Кузовлево - Светлый (км 0+...  1.466047
# ул. Вершинина                                       1.508352
# Чекистский тракт                                    1.607674
# ул. Косарева от ул. Косарева, 1/1 до ул. Косаре...  1.657650
# ул. Киевская                                        1.732881
# ул. Б. Хмельницкого                                 1.999478
# ул. Мичурина от ул. Мичурина 37 до ул.Мичурина 106  2.396031
# ул. Герцена                                         2.559628
# ул. Пролетарская от ул. Пролетарская, 2 до пр. ...  2.693681
# Иркутский тракт                                     2.957875
# ул. Водяная                                         3.839442

# %%
columns_renaming = {
    "totals_after": "Кол-во ДТП после ремонта",
    "totals_before": "Кол-во ДТП до ремонта",
    "days_after": "Дней наблюдения после ремонта",
    "days_before": "Дней наблюдения до ремонта",
    "year": "Год выполнения ремонта",
    "ratio_after": "Частота ДТП (случаев в год) после ремонта",
    "ratio_before": "Частота ДТП (случаев в год) до ремонта",
    "change": "Изменение частоты ДТП"
}
df_to_save.index.name = "Отремонтированный участок"
df_to_save.rename(columns=columns_renaming).to_excel("dtp_rate_changes.xlsx")
